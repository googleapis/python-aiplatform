# %%
from google.cloud import aiplatform

# %%
aiplatform.init(project='sashaproject-1', location='us-central1' )

# %%
import kfp.v2.components as comp

# %%
#             if key in init_arg_names:
#                 serialized_args['init'][key] = value
#                 #runner_args.append(f'--{INIT_KEY}.{key}={value}')
#             elif key in method_arg_names:
#                 serialized_args['method'][key] = value
#                 runner_args.append(f'--{METHOD_KEY}.{key}={value}')
#             elif key == 'staging_bucket':
#                 pass
                #runner_args.append(f'--staging_bucket={value}')

# %%
import importlib
import subprocess
import inspect
import json
from kfp.v2 import dsl
from kfp import components
import kfp
import re

from google.cloud import aiplatform

INIT_KEY = 'init'
METHOD_KEY = 'method'

gcs_csv_path = 'gs://ucaip-mb-sasha-dev/data/abalone_train.csv'
    
def method_converter(method, should_serialize_init=False):
    method_signature = inspect.signature(method)
    method_name = method.__name__
    
    if inspect.ismethod(method):
        cls_name = method.__self__.__name__
        init_signature = inspect.signature(method.__self__.__init__)
    else:
        cls = getattr(inspect.getmodule(method),
                      method.__qualname__.split('.<locals>', 1)[0].rsplit('.', 1)[0],
                      None)
        cls_name = cls.__name__
        init_signature = inspect.signature(cls.__init__)
    
    method_arg_names = set(method_signature.parameters.keys())
    init_arg_names = set(init_signature.parameters.keys()) if should_serialize_init else set([])
    
    
    subcommand = [
        'python3',
        'auto_runner.py',
        f'--cls_name={cls_name}',
        f'--method_name={method_name}'
    ]
    
    def make_args(sa):
        additional_args = []
        for key, args in sa.items():
            for arg_key, value in args.items():
                additional_args.append(f"    - --{key}.{arg_key}={value}")
        return '\n'.join(additional_args)

    def f(**kwargs):
        runner_args = []
        inputs = ["inputs:"]
        input_args = []
        input_kwargs = {}
        
        serialized_args = {"init": {}, "method": {}}
        
        for key, value in kwargs.items():
            prefix_key = "init" if key in init_arg_names else "method"
            if isinstance(value, kfp.dsl._pipeline_param.PipelineParam):
                name = key
                inputs.append("- {name: %s, type: Artifact}" % (name))
                input_args.append("""
    - --%s
    - {inputUri: %s}
""" % (f'{prefix_key}.{key}', key))
                input_kwargs[key] = value
            else:
                serialized_args[prefix_key][key] = value
       
        inputs = "\n".join(inputs) if len(inputs) > 1 else ''
        input_args = "\n".join(input_args) if input_args else ''
        component_text = """
name: %s-%s
# %s
outputs:
- {name: resource_name_output, type: Artifact}
implementation:
  container:
    image: gcr.io/sashaproject-1/mb_sdk_component:latest
    command:
    - python3
    - remote_runner.py
    - --cls_name=%s
    - --method_name=%s
# %s
    args:
    - --resource_name_output_uri
    - {outputUri: resource_name_output}
# %s
""" % (cls_name,
       method_name,
       inputs,
       cls_name,
       method_name,
       make_args(serialized_args),
      input_args)
        
        print(component_text)
        
        return components.load_component_from_text(component_text)(**input_kwargs)
        #return subprocess.check_output(' '.join(subcommand + runner_args), shell=True)

    return f

# %%
from google.cloud import aiplatform
from kfp import dsl

# %%
from kfp.v2 import dsl
from kfp.v2 import compiler



@kfp.v2.dsl.pipeline(name='datasetcreatetest')
def pipeline():
    op = DatasetCreateOp(
      project='sashaproject-1',
      display_name='abalone',
      metadata_schema_uri=aiplatform.schema.dataset.metadata.tabular,
      gcs_source=gcs_csv_path)
    print(op)
    
compiler.Compiler().compile(pipeline_func=pipeline,
                            pipeline_root='gs://ucaip-mb-sasha-dev/pipeline-dev',
                            output_path='pipeline.json')
# Out:
# ['python3', 'auto_runner.py', '--cls_name=Dataset', '--method_name=create']
# []
# {'init': {}, 'method': {'project': 'sashaproject-1', 'display_name': 'abalone', 'metadata_schema_uri': 'gs://google-cloud-aiplatform/schema/dataset/metadata/tabular_1.0.0.yaml', 'gcs_source': 'gs://ucaip-mb-sasha-dev/data/abalone_train.csv'}}
#
# name: Dataset-create
#
# outputs:
# - {name: resource_name_output, type: Artifact}
# implementation:
#   container:
#     image: gcr.io/sashaproject-1/mb_sdk_component:latest
#     command:
#     - python3
#     - remote_runner.py
#     - --cls_name=Dataset
#     - --method_name=create
#     - --method.project=sashaproject-1
#     - --method.display_name=abalone
#     - --method.metadata_schema_uri=gs://google-cloud-aiplatform/schema/dataset/metadata/tabular_1.0.0.yaml
#     - --method.gcs_source=gs://ucaip-mb-sasha-dev/data/abalone_train.csv
#     args:
#     - --resource_name_output_uri
#     - {outputUri: resource_name_output}
#
#
# {'ContainerOp': {'is_exit_handler': False, 'human_name': 'Dataset-create', 'display_name': None, 'name': 'dataset-create', 'node_selector': {}, 'volumes': [], 'tolerations': [], 'affinity': {}, 'pod_annotations': {}, 'pod_labels': {}, 'retry_policy': None, 'num_retries': 0, 'timeout': 0, 'init_containers': [], 'sidecars': [], 'loop_args': None, '_inputs': [], 'dependent_names': [], 'attrs_with_pipelineparams': ['node_selector', 'volumes', 'pod_annotations', 'pod_labels', 'num_retries', 'init_containers', 'sidecars', 'tolerations', '_container', 'artifact_arguments', '_parameter_arguments'], '_container': {'args': ['--resource_name_output_uri',
#           "{{$.outputs.artifacts['resource_name_output'].uri}}"],
#  'command': ['python3',
#              'remote_runner.py',
#              '--cls_name=Dataset',
#              '--method_name=create',
#              '--method.project=sashaproject-1',
#              '--method.display_name=abalone',
#              '--method.metadata_schema_uri=gs://google-cloud-aiplatform/schema/dataset/metadata/tabular_1.0.0.yaml',
#              '--method.gcs_source=gs://ucaip-mb-sasha-dev/data/abalone_train.csv'],
#  'env': None,
#  'env_from': None,
#  'image': 'gcr.io/sashaproject-1/mb_sdk_component:latest',
#  'image_pull_policy': None,
#  'lifecycle': None,
#  'liveness_probe': None,
#  'ports': None,
#  'readiness_probe': None,
#  'resources': None,
#  'security_context': None,
#  'stdin': None,
#  'stdin_once': None,
#  'termination_message_path': None,
#  'termination_message_policy': None,
#  'tty': None,
#  'volume_devices': None,
#  'volume_mounts': None,
#  'working_dir': None}, 'add_env_from': <function deprecation_warning.<locals>._wrapped at 0x7f614b3371e0>, 'add_env_variable': <function deprecation_warning.<locals>._wrapped at 0x7f614b24f488>, 'add_port': <function deprecation_warning.<locals>._wrapped at 0x7f614b24f378>, 'add_resource_limit': <function deprecation_warning.<locals>._wrapped at 0x7f614b24f268>, 'add_resource_request': <function deprecation_warning.<locals>._wrapped at 0x7f614b24f158>, 'add_volume_devices': <function deprecation_warning.<locals>._wrapped at 0x7f614b24f048>, 'add_volume_mount': <function deprecation_warning.<locals>._wrapped at 0x7f614b2551e0>, 'set_cpu_request': <function deprecation_warning.<locals>._wrapped at 0x7f614b255378>, 'set_ephemeral_storage_limit': <function deprecation_warning.<locals>._wrapped at 0x7f614b255048>, 'set_ephemeral_storage_request': <function deprecation_warning.<locals>._wrapped at 0x7f614b255268>, 'set_image_pull_policy': <function deprecation_warning.<locals>._wrapped at 0x7f614b255488>, 'set_lifecycle': <function deprecation_warning.<locals>._wrapped at 0x7f614b337510>, 'set_liveness_probe': <function deprecation_warning.<locals>._wrapped at 0x7f614b337488>, 'set_memory_request': <function deprecation_warning.<locals>._wrapped at 0x7f614b67ab70>, 'set_readiness_probe': <function deprecation_warning.<locals>._wrapped at 0x7f614b67abf8>, 'set_security_context': <function deprecation_warning.<locals>._wrapped at 0x7f614b5659d8>, 'set_stdin': <function deprecation_warning.<locals>._wrapped at 0x7f614b5657b8>, 'set_stdin_once': <function deprecation_warning.<locals>._wrapped at 0x7f614b565ea0>, 'set_termination_message_path': <function deprecation_warning.<locals>._wrapped at 0x7f614b565d08>, 'set_termination_message_policy': <function deprecation_warning.<locals>._wrapped at 0x7f614b565950>, 'set_tty': <function deprecation_warning.<locals>._wrapped at 0x7f614b565d90>, 'input_artifact_paths': {}, 'artifact_arguments': {}, 'file_outputs': {'resource_name_output': "{{$.outputs.artifacts['resource_name_output'].uri}}"}, 'output_artifact_paths': {}, '_metadata': ComponentSpec(name='Dataset-create', description=None, metadata=None, inputs=None, outputs=[OutputSpec(name='resource_name_output', type='Artifact', description=None, annotations=None)], implementation=ContainerImplementation(container=ContainerSpec(image='gcr.io/sashaproject-1/mb_sdk_component:latest', command=['python3', 'remote_runner.py', '--cls_name=Dataset', '--method_name=create', '--method.project=sashaproject-1', '--method.display_name=abalone', '--method.metadata_schema_uri=gs://google-cloud-aiplatform/schema/dataset/metadata/tabular_1.0.0.yaml', '--method.gcs_source=gs://ucaip-mb-sasha-dev/data/abalone_train.csv'], args=['--resource_name_output_uri', OutputUriPlaceholder(output_name='resource_name_output')], env=None, file_outputs=None)), version='google.com/cloud/pipelines/component/v1'), '_parameter_arguments': None, 'execution_options': ExecutionOptionsSpec(retry_strategy=None, caching_strategy=CachingStrategySpec(max_cache_staleness=None)), 'outputs': {'resource_name_output': {{pipelineparam:op=dataset-create;name=resource_name_output}}}, 'output': {{pipelineparam:op=dataset-create;name=resource_name_output}}, 'pvolumes': {}, 'pvolume': None, '_container_spec': image: "gcr.io/sashaproject-1/mb_sdk_component:latest"
# command: "python3"
# command: "remote_runner.py"
# command: "--cls_name=Dataset"
# command: "--method_name=create"
# command: "--method.project=sashaproject-1"
# command: "--method.display_name=abalone"
# command: "--method.metadata_schema_uri=gs://google-cloud-aiplatform/schema/dataset/metadata/tabular_1.0.0.yaml"
# command: "--method.gcs_source=gs://ucaip-mb-sasha-dev/data/abalone_train.csv"
# args: "--resource_name_output_uri"
# args: "{{$.outputs.artifacts[\'resource_name_output\'].uri}}"
# , 'task_spec': task_info {
#   name: "task-dataset-create"
# }
# component_ref {
#   name: "comp-dataset-create"
# }
# , 'importer_specs': {}, 'component_spec': output_definitions {
#   artifacts {
#     key: "resource_name_output"
#     value {
#       artifact_type {
#         instance_schema: "properties:\ntitle: kfp.Artifact\ntype: object\n"
#       }
#     }
#   }
# }
# executor_label: "exec-dataset-create"
# }}

# %%
aiplatform.pipelines.Datacr

DatasetCreateOp = method_converter(aiplatform.Dataset.create)

CustomContainerTrainingJobRunOp = method_converter(aiplatform.CustomContainerTrainingJob.run,
                                                  should_serialize_init=True)

ModelDeployOp = method_converter(aiplatform.Model.deploy, should_serialize_init=True)

# %%
@kfp.v2.dsl.pipeline(name='customtrainingtest')
def pipeline():
    dataset_create_op = DatasetCreateOp(
      project='sashaproject-1',
      display_name='bq_iris_dataset',
      bq_source=f'bq://sashaproject-1.ml_datasets.iris',
      metadata_schema_uri=aiplatform.schema.dataset.metadata.tabular)
    
    custom_training_op = CustomContainerTrainingJobRunOp(
        project='sashaproject-1',
        container_uri='gcr.io/sashaproject-1/test-custom-container:latest',
        model_serving_container_image_uri='gcr.io/cloud-aiplatform/prediction/tf2-cpu.2-2:latest',
        dataset=dataset_create_op.outputs['resource_name_output'],
        #dataset='projects/40556267596/locations/us-central1/datasets/1832349321828237312',
        replica_count=1, 
        model_display_name='bq-iris-model',
        bigquery_destination=f'bq://sashaproject-1',
        display_name='my-training-job',
        staging_bucket='gs://ucaip-mb-sasha-dev',
    )
    
    model_deploy_op = ModelDeployOp(
        project='sashaproject-1',
        model_name=custom_training_op.outputs['resource_name_output'],
        machine_type='n1-standard-4')
    
compiler.Compiler().compile(pipeline_func=pipeline,
                        pipeline_root='gs://ucaip-mb-sasha-dev/pipeline-dev',
                        output_path='pipeline.json')
# Out:
# name: Dataset-create
#
# outputs:
# - {name: resource_name_output, type: Artifact}
# implementation:
#   container:
#     image: gcr.io/sashaproject-1/mb_sdk_component:latest
#     command:
#     - python3
#     - remote_runner.py
#     - --cls_name=Dataset
#     - --method_name=create
#     - --method.project=sashaproject-1
#     - --method.display_name=bq_iris_dataset
#     - --method.bq_source=bq://sashaproject-1.ml_datasets.iris
#     - --method.metadata_schema_uri=gs://google-cloud-aiplatform/schema/dataset/metadata/tabular_1.0.0.yaml
#     args:
#     - --resource_name_output_uri
#     - {outputUri: resource_name_output}
#
#
#
# name: CustomContainerTrainingJob-run
# inputs:
# - {name: dataset, type: Artifact}
# outputs:
# - {name: resource_name_output, type: Artifact}
# implementation:
#   container:
#     image: gcr.io/sashaproject-1/mb_sdk_component:latest
#     command:
#     - python3
#     - remote_runner.py
#     - --cls_name=CustomContainerTrainingJob
#     - --method_name=run
#     - --init.project=sashaproject-1
#     - --init.container_uri=gcr.io/sashaproject-1/test-custom-container:latest
#     - --init.model_serving_container_image_uri=gcr.io/cloud-aiplatform/prediction/tf2-cpu.2-2:latest
#     - --init.display_name=my-training-job
#     - --init.staging_bucket=gs://ucaip-mb-sasha-dev
#     - --method.replica_count=1
#     - --method.model_display_name=bq-iris-model
#     - --method.bigquery_destination=bq://sashaproject-1
#     args:
#     - --resource_name_output_uri
#     - {outputUri: resource_name_output}
#
#     - --method.dataset
#     - {inputUri: dataset}
#
#
#
# name: Model-deploy
# inputs:
# - {name: model_name, type: Artifact}
# outputs:
# - {name: resource_name_output, type: Artifact}
# implementation:
#   container:
#     image: gcr.io/sashaproject-1/mb_sdk_component:latest
#     command:
#     - python3
#     - remote_runner.py
#     - --cls_name=Model
#     - --method_name=deploy
#     - --init.project=sashaproject-1
#     - --method.machine_type=n1-standard-4
#     args:
#     - --resource_name_output_uri
#     - {outputUri: resource_name_output}
#
#     - --init.model_name
#     - {inputUri: model_name}

# %%
# !cat pipeline.json
# Out:
# {
#   "pipelineSpec": {
#     "pipelineInfo": {
#       "name": "customtrainingtest"
#     },
#     "schemaVersion": "2.0.0",
#     "components": {
#       "comp-model-deploy": {
#         "outputDefinitions": {
#           "artifacts": {
#             "resource_name_output": {
#               "artifactType": {
#                 "instanceSchema": "properties:\ntitle: kfp.Artifact\ntype: object\n"
#               }
#             }
#           }
#         },
#         "inputDefinitions": {
#           "artifacts": {
#             "model_name": {
#               "artifactType": {
#                 "instanceSchema": "properties:\ntitle: kfp.Artifact\ntype: object\n"
#               }
#             }
#           }
#         },
#         "executorLabel": "exec-model-deploy"
#       },
#       "comp-dataset-create": {
#         "outputDefinitions": {
#           "artifacts": {
#             "resource_name_output": {
#               "artifactType": {
#                 "instanceSchema": "properties:\ntitle: kfp.Artifact\ntype: object\n"
#               }
#             }
#           }
#         },
#         "executorLabel": "exec-dataset-create"
#       },
#       "comp-customcontainertrainingjob-run": {
#         "inputDefinitions": {
#           "artifacts": {
#             "dataset": {
#               "artifactType": {
#                 "instanceSchema": "properties:\ntitle: kfp.Artifact\ntype: object\n"
#               }
#             }
#           }
#         },
#         "outputDefinitions": {
#           "artifacts": {
#             "resource_name_output": {
#               "artifactType": {
#                 "instanceSchema": "properties:\ntitle: kfp.Artifact\ntype: object\n"
#               }
#             }
#           }
#         },
#         "executorLabel": "exec-customcontainertrainingjob-run"
#       }
#     },
#     "deploymentSpec": {
#       "executors": {
#         "exec-dataset-create": {
#           "container": {
#             "command": [
#               "python3",
#               "remote_runner.py",
#               "--cls_name=Dataset",
#               "--method_name=create",
#               "--method.project=sashaproject-1",
#               "--method.display_name=bq_iris_dataset",
#               "--method.bq_source=bq://sashaproject-1.ml_datasets.iris",
#               "--method.metadata_schema_uri=gs://google-cloud-aiplatform/schema/dataset/metadata/tabular_1.0.0.yaml"
#             ],
#             "args": [
#               "--resource_name_output_uri",
#               "{{$.outputs.artifacts['resource_name_output'].uri}}"
#             ],
#             "image": "gcr.io/sashaproject-1/mb_sdk_component:latest"
#           }
#         },
#         "exec-customcontainertrainingjob-run": {
#           "container": {
#             "command": [
#               "python3",
#               "remote_runner.py",
#               "--cls_name=CustomContainerTrainingJob",
#               "--method_name=run",
#               "--init.project=sashaproject-1",
#               "--init.container_uri=gcr.io/sashaproject-1/test-custom-container:latest",
#               "--init.model_serving_container_image_uri=gcr.io/cloud-aiplatform/prediction/tf2-cpu.2-2:latest",
#               "--init.display_name=my-training-job",
#               "--init.staging_bucket=gs://ucaip-mb-sasha-dev",
#               "--method.replica_count=1",
#               "--method.model_display_name=bq-iris-model",
#               "--method.bigquery_destination=bq://sashaproject-1"
#             ],
#             "image": "gcr.io/sashaproject-1/mb_sdk_component:latest",
#             "args": [
#               "--resource_name_output_uri",
#               "{{$.outputs.artifacts['resource_name_output'].uri}}",
#               "--method.dataset",
#               "{{$.inputs.artifacts['dataset'].uri}}"
#             ]
#           }
#         },
#         "exec-model-deploy": {
#           "container": {
#             "image": "gcr.io/sashaproject-1/mb_sdk_component:latest",
#             "args": [
#               "--resource_name_output_uri",
#               "{{$.outputs.artifacts['resource_name_output'].uri}}",
#               "--init.model_name",
#               "{{$.inputs.artifacts['model_name'].uri}}"
#             ],
#             "command": [
#               "python3",
#               "remote_runner.py",
#               "--cls_name=Model",
#               "--method_name=deploy",
#               "--init.project=sashaproject-1",
#               "--method.machine_type=n1-standard-4"
#             ]
#           }
#         }
#       }
#     },
#     "root": {
#       "dag": {
#         "tasks": {
#           "task-customcontainertrainingjob-run": {
#             "taskInfo": {
#               "name": "task-customcontainertrainingjob-run"
#             },
#             "dependentTasks": [
#               "task-dataset-create"
#             ],
#             "inputs": {
#               "artifacts": {
#                 "dataset": {
#                   "taskOutputArtifact": {
#                     "outputArtifactKey": "resource_name_output",
#                     "producerTask": "task-dataset-create"
#                   }
#                 }
#               }
#             },
#             "componentRef": {
#               "name": "comp-customcontainertrainingjob-run"
#             }
#           },
#           "task-dataset-create": {
#             "componentRef": {
#               "name": "comp-dataset-create"
#             },
#             "taskInfo": {
#               "name": "task-dataset-create"
#             }
#           },
#           "task-model-deploy": {
#             "dependentTasks": [
#               "task-customcontainertrainingjob-run"
#             ],
#             "inputs": {
#               "artifacts": {
#                 "model_name": {
#                   "taskOutputArtifact": {
#                     "outputArtifactKey": "resource_name_output",
#                     "producerTask": "task-customcontainertrainingjob-run"
#                   }
#                 }
#               }
#             },
#             "componentRef": {
#               "name": "comp-model-deploy"
#             },
#             "taskInfo": {
#               "name": "task-model-deploy"
#             }
#           }
#         }
#       }
#     },
#     "sdkVersion": "kfp-1.4.0"
#   },
#   "runtimeConfig": {
#     "gcsOutputDirectory": "gs://ucaip-mb-sasha-dev/pipeline-dev"
#   }
# }

# %%
from aiplatform.pipelines import client

api_client = client.Client(project_id='sashaproject-1', region='us-central1',
                           api_key='AIzaSyB22mkgt9qWfL_wr8GH0zJX9elz3EvuouM')

# %%
api_client.create_run_from_job_spec('pipeline.json', pipeline_root='gs://ucaip-mb-sasha-dev')
# Out:
# INFO:absl:Compiled JSON request: {"pipelineSpec": {"pipelineInfo": {"name": "customtrainingtest"}, "schemaVersion": "2.0.0", "components": {"comp-model-deploy": {"outputDefinitions": {"artifacts": {"resource_name_output": {"artifactType": {"instanceSchema": "properties:\ntitle: kfp.Artifact\ntype: object\n"}}}}, "inputDefinitions": {"artifacts": {"model_name": {"artifactType": {"instanceSchema": "properties:\ntitle: kfp.Artifact\ntype: object\n"}}}}, "executorLabel": "exec-model-deploy"}, "comp-dataset-create": {"outputDefinitions": {"artifacts": {"resource_name_output": {"artifactType": {"instanceSchema": "properties:\ntitle: kfp.Artifact\ntype: object\n"}}}}, "executorLabel": "exec-dataset-create"}, "comp-customcontainertrainingjob-run": {"inputDefinitions": {"artifacts": {"dataset": {"artifactType": {"instanceSchema": "properties:\ntitle: kfp.Artifact\ntype: object\n"}}}}, "outputDefinitions": {"artifacts": {"resource_name_output": {"artifactType": {"instanceSchema": "properties:\ntitle: kfp.Artifact\ntype: object\n"}}}}, "executorLabel": "exec-customcontainertrainingjob-run"}}, "deploymentSpec": {"executors": {"exec-dataset-create": {"container": {"command": ["python3", "remote_runner.py", "--cls_name=Dataset", "--method_name=create", "--method.project=sashaproject-1", "--method.display_name=bq_iris_dataset", "--method.bq_source=bq://sashaproject-1.ml_datasets.iris", "--method.metadata_schema_uri=gs://google-cloud-aiplatform/schema/dataset/metadata/tabular_1.0.0.yaml"], "args": ["--resource_name_output_uri", "{{$.outputs.artifacts['resource_name_output'].uri}}"], "image": "gcr.io/sashaproject-1/mb_sdk_component:latest"}}, "exec-customcontainertrainingjob-run": {"container": {"command": ["python3", "remote_runner.py", "--cls_name=CustomContainerTrainingJob", "--method_name=run", "--init.project=sashaproject-1", "--init.container_uri=gcr.io/sashaproject-1/test-custom-container:latest", "--init.model_serving_container_image_uri=gcr.io/cloud-aiplatform/prediction/tf2-cpu.2-2:latest", "--init.display_name=my-training-job", "--init.staging_bucket=gs://ucaip-mb-sasha-dev", "--method.replica_count=1", "--method.model_display_name=bq-iris-model", "--method.bigquery_destination=bq://sashaproject-1"], "image": "gcr.io/sashaproject-1/mb_sdk_component:latest", "args": ["--resource_name_output_uri", "{{$.outputs.artifacts['resource_name_output'].uri}}", "--method.dataset", "{{$.inputs.artifacts['dataset'].uri}}"]}}, "exec-model-deploy": {"container": {"image": "gcr.io/sashaproject-1/mb_sdk_component:latest", "args": ["--resource_name_output_uri", "{{$.outputs.artifacts['resource_name_output'].uri}}", "--init.model_name", "{{$.inputs.artifacts['model_name'].uri}}"], "command": ["python3", "remote_runner.py", "--cls_name=Model", "--method_name=deploy", "--init.project=sashaproject-1", "--method.machine_type=n1-standard-4"]}}}}, "root": {"dag": {"tasks": {"task-customcontainertrainingjob-run": {"taskInfo": {"name": "task-customcontainertrainingjob-run"}, "dependentTasks": ["task-dataset-create"], "inputs": {"artifacts": {"dataset": {"taskOutputArtifact": {"outputArtifactKey": "resource_name_output", "producerTask": "task-dataset-create"}}}}, "componentRef": {"name": "comp-customcontainertrainingjob-run"}}, "task-dataset-create": {"componentRef": {"name": "comp-dataset-create"}, "taskInfo": {"name": "task-dataset-create"}}, "task-model-deploy": {"dependentTasks": ["task-customcontainertrainingjob-run"], "inputs": {"artifacts": {"model_name": {"taskOutputArtifact": {"outputArtifactKey": "resource_name_output", "producerTask": "task-customcontainertrainingjob-run"}}}}, "componentRef": {"name": "comp-model-deploy"}, "taskInfo": {"name": "task-model-deploy"}}}}}, "sdkVersion": "kfp-1.4.0"}, "runtimeConfig": {"gcsOutputDirectory": "gs://ucaip-mb-sasha-dev", "parameters": {}}, "name": "projects/sashaproject-1/locations/us-central1/pipelineJobs/customtrainingtest-20210317200636", "displayName": "customtrainingtest-20210317200636"}
# INFO:absl:Received server response: {"name": "projects/40556267596/locations/us-central1/pipelineJobs/customtrainingtest-20210317200636", "displayName": "customtrainingtest-20210317200636", "createTime": "2021-03-18T00:06:36.250265Z", "updateTime": "2021-03-18T00:06:36.250265Z", "pipelineSpec": {"deploymentConfig": {"@type": "type.googleapis.com/ml_pipelines.PipelineDeploymentConfig", "executors": {"exec-dataset-create": {"container": {"image": "gcr.io/sashaproject-1/mb_sdk_component:latest", "command": ["python3", "remote_runner.py", "--cls_name=Dataset", "--method_name=create", "--method.project=sashaproject-1", "--method.display_name=bq_iris_dataset", "--method.bq_source=bq://sashaproject-1.ml_datasets.iris", "--method.metadata_schema_uri=gs://google-cloud-aiplatform/schema/dataset/metadata/tabular_1.0.0.yaml"], "args": ["--resource_name_output_uri", "{{$.outputs.artifacts['resource_name_output'].uri}}"]}}, "exec-customcontainertrainingjob-run": {"container": {"image": "gcr.io/sashaproject-1/mb_sdk_component:latest", "command": ["python3", "remote_runner.py", "--cls_name=CustomContainerTrainingJob", "--method_name=run", "--init.project=sashaproject-1", "--init.container_uri=gcr.io/sashaproject-1/test-custom-container:latest", "--init.model_serving_container_image_uri=gcr.io/cloud-aiplatform/prediction/tf2-cpu.2-2:latest", "--init.display_name=my-training-job", "--init.staging_bucket=gs://ucaip-mb-sasha-dev", "--method.replica_count=1", "--method.model_display_name=bq-iris-model", "--method.bigquery_destination=bq://sashaproject-1"], "args": ["--resource_name_output_uri", "{{$.outputs.artifacts['resource_name_output'].uri}}", "--method.dataset", "{{$.inputs.artifacts['dataset'].uri}}"]}}, "exec-model-deploy": {"container": {"image": "gcr.io/sashaproject-1/mb_sdk_component:latest", "command": ["python3", "remote_runner.py", "--cls_name=Model", "--method_name=deploy", "--init.project=sashaproject-1", "--method.machine_type=n1-standard-4"], "args": ["--resource_name_output_uri", "{{$.outputs.artifacts['resource_name_output'].uri}}", "--init.model_name", "{{$.inputs.artifacts['model_name'].uri}}"]}}}}, "components": {"comp-model-deploy": {"inputDefinitions": {"artifacts": {"model_name": {"artifactType": {"instanceSchema": "properties:\ntitle: kfp.Artifact\ntype: object\n"}}}}, "outputDefinitions": {"artifacts": {"resource_name_output": {"artifactType": {"instanceSchema": "properties:\ntitle: kfp.Artifact\ntype: object\n"}}}}, "executorLabel": "exec-model-deploy"}, "comp-dataset-create": {"outputDefinitions": {"artifacts": {"resource_name_output": {"artifactType": {"instanceSchema": "properties:\ntitle: kfp.Artifact\ntype: object\n"}}}}, "executorLabel": "exec-dataset-create"}, "comp-customcontainertrainingjob-run": {"inputDefinitions": {"artifacts": {"dataset": {"artifactType": {"instanceSchema": "properties:\ntitle: kfp.Artifact\ntype: object\n"}}}}, "outputDefinitions": {"artifacts": {"resource_name_output": {"artifactType": {"instanceSchema": "properties:\ntitle: kfp.Artifact\ntype: object\n"}}}}, "executorLabel": "exec-customcontainertrainingjob-run"}}, "schemaVersion": "2.0.0", "root": {"dag": {"tasks": {"task-customcontainertrainingjob-run": {"taskInfo": {"name": "task-customcontainertrainingjob-run"}, "inputs": {"artifacts": {"dataset": {"taskOutputArtifact": {"producerTask": "task-dataset-create", "outputArtifactKey": "resource_name_output"}}}}, "dependentTasks": ["task-dataset-create"], "componentRef": {"name": "comp-customcontainertrainingjob-run"}}, "task-dataset-create": {"taskInfo": {"name": "task-dataset-create"}, "componentRef": {"name": "comp-dataset-create"}}, "task-model-deploy": {"taskInfo": {"name": "task-model-deploy"}, "inputs": {"artifacts": {"model_name": {"taskOutputArtifact": {"producerTask": "task-customcontainertrainingjob-run", "outputArtifactKey": "resource_name_output"}}}}, "dependentTasks": ["task-customcontainertrainingjob-run"], "componentRef": {"name": "comp-model-deploy"}}}}}, "sdkVersion": "k ...
# INFO:absl:Execution triggered. Job name: projects/40556267596/locations/us-central1/pipelineJobs/customtrainingtest-20210317200636
# See the Pipeline job <a href="https://console.cloud.google.com/ai/platform/pipelines/runs/customtrainingtest-20210317200636?e=CaipPipelinesAlphaLaunch::CaipPipelinesAlphaEnabled,BackendzOverridingLaunch::BackendzOverridingEnabled,CloudAiLaunch::CloudAiEnabled&project=sashaproject-1" target="_blank" >here</a>.
# {'name': 'projects/40556267596/locations/us-central1/pipelineJobs/customtrainingtest-20210317200636',
#  'displayName': 'customtrainingtest-20210317200636',
#  'createTime': '2021-03-18T00:06:36.250265Z',
#  'updateTime': '2021-03-18T00:06:36.250265Z',
#  'pipelineSpec': {'deploymentConfig': {'@type': 'type.googleapis.com/ml_pipelines.PipelineDeploymentConfig',
#    'executors': {'exec-dataset-create': {'container': {'image': 'gcr.io/sashaproject-1/mb_sdk_component:latest',
#       'command': ['python3',
#        'remote_runner.py',
#        '--cls_name=Dataset',
#        '--method_name=create',
#        '--method.project=sashaproject-1',
#        '--method.display_name=bq_iris_dataset',
#        '--method.bq_source=bq://sashaproject-1.ml_datasets.iris',
#        '--method.metadata_schema_uri=gs://google-cloud-aiplatform/schema/dataset/metadata/tabular_1.0.0.yaml'],
#       'args': ['--resource_name_output_uri',
#        "{{$.outputs.artifacts['resource_name_output'].uri}}"]}},
#     'exec-customcontainertrainingjob-run': {'container': {'image': 'gcr.io/sashaproject-1/mb_sdk_component:latest',
#       'command': ['python3',
#        'remote_runner.py',
#        '--cls_name=CustomContainerTrainingJob',
#        '--method_name=run',
#        '--init.project=sashaproject-1',
#        '--init.container_uri=gcr.io/sashaproject-1/test-custom-container:latest',
#        '--init.model_serving_container_image_uri=gcr.io/cloud-aiplatform/prediction/tf2-cpu.2-2:latest',
#        '--init.display_name=my-training-job',
#        '--init.staging_bucket=gs://ucaip-mb-sasha-dev',
#        '--method.replica_count=1',
#        '--method.model_display_name=bq-iris-model',
#        '--method.bigquery_destination=bq://sashaproject-1'],
#       'args': ['--resource_name_output_uri',
#        "{{$.outputs.artifacts['resource_name_output'].uri}}",
#        '--method.dataset',
#        "{{$.inputs.artifacts['dataset'].uri}}"]}},
#     'exec-model-deploy': {'container': {'image': 'gcr.io/sashaproject-1/mb_sdk_component:latest',
#       'command': ['python3',
#        'remote_runner.py',
#        '--cls_name=Model',
#        '--method_name=deploy',
#        '--init.project=sashaproject-1',
#        '--method.machine_type=n1-standard-4'],
#       'args': ['--resource_name_output_uri',
#        "{{$.outputs.artifacts['resource_name_output'].uri}}",
#        '--init.model_name',
#        "{{$.inputs.artifacts['model_name'].uri}}"]}}}},
#   'components': {'comp-model-deploy': {'inputDefinitions': {'artifacts': {'model_name': {'artifactType': {'instanceSchema': 'properties:\ntitle: kfp.Artifact\ntype: object\n'}}}},
#     'outputDefinitions': {'artifacts': {'resource_name_output': {'artifactType': {'instanceSchema': 'properties:\ntitle: kfp.Artifact\ntype: object\n'}}}},
#     'executorLabel': 'exec-model-deploy'},
#    'comp-dataset-create': {'outputDefinitions': {'artifacts': {'resource_name_output': {'artifactType': {'instanceSchema': 'properties:\ntitle: kfp.Artifact\ntype: object\n'}}}},
#     'executorLabel': 'exec-dataset-create'},
#    'comp-customcontainertrainingjob-run': {'inputDefinitions': {'artifacts': {'dataset': {'artifactType': {'instanceSchema': 'properties:\ntitle: kfp.Artifact\ntype: object\n'}}}},
#     'outputDefinitions': {'artifacts': {'resource_name_output': {'artifactType': {'instanceSchema': 'properties:\ntitle: kfp.Artifact\ntype: object\n'}}}},
#     'executorLabel': 'exec-customcontainertrainingjob-run'}},
#   'schemaVersion': '2.0.0',
#   'root': {'dag': {'tasks': {'task-customcontainertrainingjob-run': {'taskInfo': {'name': 'task-customcontainertrainingjob-run'},
#       'inputs': {'artifacts': {'dataset': {'taskOutputArtifact': {'producerTask': 'task-dataset-create',
#           'outputArtifactKey': 'resource_name_output'}}}},
#       'dependentTasks': ['task-dataset-create'],
#       'componentRef': {'name': 'comp-customcontainertrainingjob-run'}},
#      'task-dataset-create': {'taskInfo': {'name': 'task-dataset-create'},
#       'componentRef': {'name': 'comp-dataset-create'}},
#      'task-model-deploy': {'taskInfo': {'name': 'task-model-deploy'},
#       'inputs': {'artifacts': {'model_name': {'taskOutputArtifact': {'producerTask': 'task-customcontainertrainingjob-run',
#           'outputArtifactKey': 'resource_name_output'}}}},
#       'dependentTasks': ['task-customcontainertrainingjob-run'],
#       'componentRef': {'name': 'comp-model-deploy'}}}}},
#   'sdkVersion': 'kfp-1.4.0',
#   'pipelineInfo': {'name': 'customtrainingtest'},
#   'deploymentSpec': {'executors': {'exec-dataset-create': {'container': {'image': 'gcr.io/sashaproject-1/mb_sdk_component:latest',
#       'command': ['python3',
#        'remote_runner.py',
#        '--cls_name=Dataset',
#        '--method_name=create',
#        '--method.project=sashaproject-1',
#        '--method.display_name=bq_iris_dataset',
#        '--method.bq_source=bq://sashaproject-1.ml_datasets.iris',
#        '--method.metadata_schema_uri=gs://google-cloud-aiplatform/schema/dataset/metadata/tabular_1.0.0.yaml'],
#       'args': ['--resource_name_output_uri',
#        "{{$.outputs.artifacts['resource_name_output'].uri}}"]}},
#     'exec-customcontainertrainingjob-run': {'container': {'image': 'gcr.io/sashaproject-1/mb_sdk_component:latest',
#       'command': ['python3',
#        'remote_runner.py',
#        '--cls_name=CustomContainerTrainingJob',
#        '--method_name=run',
#        '--init.project=sashaproject-1',
#        '--init.container_uri=gcr.io/sashaproject-1/test-custom-container:latest',
#        '--init.model_serving_container_image_uri=gcr.io/cloud-aiplatform/prediction/tf2-cpu.2-2:latest',
#        '--init.display_name=my-training-job',
#        '--init.staging_bucket=gs://ucaip-mb-sasha-dev',
#        '--method.replica_count=1',
#        '--method.model_display_name=bq-iris-model',
#        '--method.bigquery_destination=bq://sashaproject-1'],
#       'args': ['--resource_name_output_uri',
#        "{{$.outputs.artifacts['resource_name_output'].uri}}",
#        '--method.dataset',
#        "{{$.inputs.artifacts['dataset'].uri}}"]}},
#     'exec-model-deploy': {'container': {'image': 'gcr.io/sashaproject-1/mb_sdk_component:latest',
#       'command': ['python3',
#        'remote_runner.py',
#        '--cls_name=Model',
#        '--method_name=deploy',
#        '--init.project=sashaproject-1',
#        '--method.machine_type=n1-standard-4'],
#       'args': ['--resource_name_output_uri',
#        "{{$.outputs.artifacts['resource_name_output'].uri}}",
#        '--init.model_name',
#        "{{$.inputs.artifacts['model_name'].uri}}"]}}}}},
#  'state': 'PIPELINE_STATE_PENDING',
#  'runtimeConfig': {'gcsOutputDirectory': 'gs://ucaip-mb-sasha-dev'}}

# %%
api_client.get_job('customtrainingtest-20210317152513')
# Out:
# {'name': 'projects/40556267596/locations/us-central1/pipelineJobs/customtrainingtest-20210317152513',
#  'displayName': 'customtrainingtest-20210317152513',
#  'createTime': '2021-03-17T19:25:13.705213Z',
#  'startTime': '2021-03-17T19:25:44.872367Z',
#  'endTime': '2021-03-17T19:27:32.591102Z',
#  'updateTime': '2021-03-17T19:27:32.591102Z',
#  'pipelineSpec': {'deploymentConfig': {'@type': 'type.googleapis.com/ml_pipelines.PipelineDeploymentConfig',
#    'executors': {'exec-dataset-create': {'container': {'image': 'gcr.io/sashaproject-1/mb_sdk_component:latest',
#       'command': ['python3',
#        'remote_runner.py',
#        '--cls_name=Dataset',
#        '--method_name=create',
#        '--method.project=sashaproject-1',
#        '--method.display_name=abalone',
#        '--method.metadata_schema_uri=gs://google-cloud-aiplatform/schema/dataset/metadata/tabular_1.0.0.yaml',
#        '--method.gcs_source=gs://ucaip-mb-sasha-dev/data/abalone_train.csv'],
#       'args': ['--resource_name_output_uri',
#        "{{$.outputs.artifacts['resource_name_output'].uri}}"]}},
#     'exec-customcontainertrainingjob-run': {'container': {'image': 'gcr.io/sashaproject-1/mb_sdk_component:latest',
#       'command': ['python3',
#        'remote_runner.py',
#        '--cls_name=CustomContainerTrainingJob',
#        '--method_name=run',
#        '--init.project=sashaproject-1',
#        '--init.location=us-central1',
#        '--init.container_uri=gcr.io/sashaproject-1/test-custom-container:latest',
#        '--init.model_serving_container_image_uri=gcr.io/cloud-aiplatform/prediction/tf2-cpu.2-2:latest',
#        '--init.display_name=my-training-job',
#        '--init.staging_bucket=gs://ucaip-mb-sasha-dev',
#        '--method.replica_count=1',
#        '--method.model_display_name=bq-iris-model',
#        '--method.bigquery_destination=bq://sashaproject-1'],
#       'args': ['--resource_name_output_uri',
#        "{{$.outputs.artifacts['resource_name_output'].uri}}",
#        '--method.dataset',
#        "{{$.inputs.artifacts['dataset'].uri}}"]}}}},
#   'components': {'comp-customcontainertrainingjob-run': {'inputDefinitions': {'artifacts': {'dataset': {'artifactType': {'instanceSchema': 'properties:\ntitle: kfp.Artifact\ntype: object\n'}}}},
#     'outputDefinitions': {'artifacts': {'resource_name_output': {'artifactType': {'instanceSchema': 'properties:\ntitle: kfp.Artifact\ntype: object\n'}}}},
#     'executorLabel': 'exec-customcontainertrainingjob-run'},
#    'comp-dataset-create': {'outputDefinitions': {'artifacts': {'resource_name_output': {'artifactType': {'instanceSchema': 'properties:\ntitle: kfp.Artifact\ntype: object\n'}}}},
#     'executorLabel': 'exec-dataset-create'}},
#   'schemaVersion': '2.0.0',
#   'root': {'dag': {'tasks': {'task-dataset-create': {'taskInfo': {'name': 'task-dataset-create'},
#       'componentRef': {'name': 'comp-dataset-create'}},
#      'task-customcontainertrainingjob-run': {'taskInfo': {'name': 'task-customcontainertrainingjob-run'},
#       'inputs': {'artifacts': {'dataset': {'taskOutputArtifact': {'producerTask': 'task-dataset-create',
#           'outputArtifactKey': 'resource_name_output'}}}},
#       'dependentTasks': ['task-dataset-create'],
#       'componentRef': {'name': 'comp-customcontainertrainingjob-run'}}}}},
#   'sdkVersion': 'kfp-1.4.0',
#   'pipelineInfo': {'name': 'customtrainingtest'},
#   'deploymentSpec': {'executors': {'exec-dataset-create': {'container': {'image': 'gcr.io/sashaproject-1/mb_sdk_component:latest',
#       'command': ['python3',
#        'remote_runner.py',
#        '--cls_name=Dataset',
#        '--method_name=create',
#        '--method.project=sashaproject-1',
#        '--method.display_name=abalone',
#        '--method.metadata_schema_uri=gs://google-cloud-aiplatform/schema/dataset/metadata/tabular_1.0.0.yaml',
#        '--method.gcs_source=gs://ucaip-mb-sasha-dev/data/abalone_train.csv'],
#       'args': ['--resource_name_output_uri',
#        "{{$.outputs.artifacts['resource_name_output'].uri}}"]}},
#     'exec-customcontainertrainingjob-run': {'container': {'image': 'gcr.io/sashaproject-1/mb_sdk_component:latest',
#       'command': ['python3',
#        'remote_runner.py',
#        '--cls_name=CustomContainerTrainingJob',
#        '--method_name=run',
#        '--init.project=sashaproject-1',
#        '--init.location=us-central1',
#        '--init.container_uri=gcr.io/sashaproject-1/test-custom-container:latest',
#        '--init.model_serving_container_image_uri=gcr.io/cloud-aiplatform/prediction/tf2-cpu.2-2:latest',
#        '--init.display_name=my-training-job',
#        '--init.staging_bucket=gs://ucaip-mb-sasha-dev',
#        '--method.replica_count=1',
#        '--method.model_display_name=bq-iris-model',
#        '--method.bigquery_destination=bq://sashaproject-1'],
#       'args': ['--resource_name_output_uri',
#        "{{$.outputs.artifacts['resource_name_output'].uri}}",
#        '--method.dataset',
#        "{{$.inputs.artifacts['dataset'].uri}}"]}}}}},
#  'state': 'PIPELINE_STATE_FAILED',
#  'jobDetail': {'pipelineContext': {'name': 'projects/40556267596/locations/us-central1/metadataStores/default/contexts/customtrainingtest',
#    'displayName': 'customtrainingtest',
#    'instanceSchemaTitle': 'aiplatform.Pipeline',
#    'instanceSchema': '\ntitle: aiplatform.Pipeline\ntype: object\n',
#    'etag': '1615995448739',
#    'createTime': '2021-03-17T15:37:28.739Z',
#    'updateTime': '2021-03-17T15:37:28.739Z'},
#   'pipelineRunContext': {'name': 'projects/40556267596/locations/us-central1/metadataStores/default/contexts/customtrainingtest-20210317152513',
#    'displayName': 'customtrainingtest-20210317152513',
#    'instanceSchemaTitle': 'aiplatform.PipelineRun',
#    'instanceSchema': '\ntitle: aiplatform.PipelineRun\ntype: object\n',
#    'etag': '1616009145296',
#    'createTime': '2021-03-17T19:25:45.296Z',
#    'updateTime': '2021-03-17T19:25:45.296Z'},
#   'taskDetails': [{'taskId': '-8869698728617836544',
#     'taskName': 'task-dataset-create',
#     'createTime': '2021-03-17T19:25:44.872367Z',
#     'startTime': '2021-03-17T19:25:48.791476Z',
#     'endTime': '2021-03-17T19:26:23.303727Z',
#     'executorDetail': {'containerDetail': {'mainJob': 'projects/40556267596/locations/us-central1/customJobs/8842685926946635776'}},
#     'state': 'SUCCEEDED',
#     'execution': {'name': 'projects/40556267596/locations/us-central1/metadataStores/default/executions/15490121423522611515',
#      'displayName': 'task-dataset-create',
#      'instanceSchemaTitle': 'aiplatform.ContainerExecution',
#      'state': 'COMPLETE',
#      'etag': '1616009182413',
#      'createTime': '2021-03-17T19:25:45.777Z',
#      'updateTime': '2021-03-17T19:26:22.413Z'},
#     'outputs': {'resource_name_output': {'artifacts': [{'name': 'projects/40556267596/locations/us-central1/metadataStores/default/artifacts/10785537882611871017',
#         'displayName': 'resource_name_output',
#         'instanceSchemaTitle': 'kfp.Artifact',
#         'uri': 'gs://ucaip-mb-sasha-dev/40556267596/customtrainingtest-20210317152513/task-dataset-create_-8869698728617836544/resource_name_output',
#         'etag': '1616009182754',
#         'createTime': '2021-03-17T19:25:47.953Z',
#         'updateTime': '2021-03-17T19:26:22.754Z',
#         'state': 'LIVE'}]}}},
#    {'taskId': '4965359326664327168',
#     'taskName': 'task-customcontainertrainingjob-run',
#     'createTime': '2021-03-17T19:25:44.872367Z',
#     'startTime': '2021-03-17T19:26:27.188597Z',
#     'endTime': '2021-03-17T19:27:32.312878Z',
#     'executorDetail': {'containerDetail': {'mainJob': 'projects/40556267596/locations/us-central1/customJobs/7400408146281234432'}},
#     'state': 'FAILED',
#     'execution': {'name': 'projects/40556267596/locations/us-central1/metadataStores/default/executions/1515654757754287792',
#      'displayName': 'task-customcontainertrainingjob-run',
#      'instanceSchemaTitle': 'aiplatform.ContainerExecution',
#      'state': 'FAILED',
#      'etag': '1616009251546',
#      'createTime': '2021-03-17T19:26:23.942Z',
#      'updateTime': '2021-03-17T19:27:31.546Z'},
#     'error': {'code': 9,
#      'message': 'Polled executor container failure: The replica workerpool0-0 exited with a non-zero status of 1. Termination reason: Error. To find out more about why your job exited please check the logs: https://console.cloud.google.com/logs/viewer?project=40556267596&resource=ml_job%2Fjob_id%2F7400408146281234432&advancedFilter=resource.type%3D%22ml_job%22%0Aresource.labels.job_id%3D%227400408146281234432%22.'},
#     'inputs': {'dataset': {'artifacts': [{'name': 'projects/40556267596/locations/us-central1/metadataStores/default/artifacts/10785537882611871017',
#         'displayName': 'resource_name_output',
#         'instanceSchemaTitle': 'kfp.Artifact',
#         'uri': 'gs://ucaip-mb-sasha-dev/40556267596/customtrainingtest-20210317152513/task-dataset-create_-8869698728617836544/resource_name_output',
#         'etag': '1616009182754',
#         'createTime': '2021-03-17T19:25:47.953Z',
#         'updateTime': '2021-03-17T19:26:22.754Z',
#         'state': 'LIVE'}]}},
#     'outputs': {'resource_name_output': {'artifacts': [{'name': 'projects/40556267596/locations/us-central1/metadataStores/default/artifacts/5993759829373308511',
#         'displayName': 'resource_name_output',
#         'instanceSchemaTitle': 'kfp.Artifact',
#         'uri': 'gs://ucaip-mb-sasha-dev/40556267596/customtrainingtest-20210317152513/task-customcontainertrainingjob-run_4965359326664327168/resource_name_output',
#         'etag': '1616009186529',
#         'createTime': '2021-03-17T19:26:26.529Z',
#         'updateTime': '2021-03-17T19:26:26.529Z',
#         'state': 'PENDING'}]}}}]},
#  'error': {'code': 9,
#   'message': 'The job failed because some tasks failed. The failed tasks are: [task-customcontainertrainingjob-run].; Job {project_number = 40556267596, job_id = 4532239706250805248} is failed due to the above error.; Failed to handle the running job: {project_number = 40556267596, job_id = 4532239706250805248}'},
#  'runtimeConfig': {'gcsOutputDirectory': 'gs://ucaip-mb-sasha-dev'}}
